# %%
age=int(input("enter age"))
citizen=input("enter citizen")
if age>18:
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# enter age18
# enter citizenindian
# not eligible for vote

# %%
age=int(input("enter age"))
citizen=input("enter citizen ");
if age>18:
    if citizen == "indian":
        print("eligible for license card")
    else:
        print("not eligible")
elif age<18:
    print("not eligible for license card")
else:
    print("not eligible")
# Out:
# enter age19
# enter citizen indian
# eligible for license card

# %%
a=int(input("enter a:"))
b=int(input("enter b:"))
c=int(input("enter c:"))
if a>b and a>c :
    print("a is greater")
elif b>a and b>c:
    print("b is greater")
else:
    print("c is greater")
# Out:
# enter a:9
# enter b:8
# enter c:16
# c is greater
