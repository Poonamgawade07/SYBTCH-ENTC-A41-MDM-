# %%
text = ' welcome to DKTE '

print('my string - ', text)
print(len(text))
print(text.upper())
print(text.lower())
print(text.capitalize())
print(text.title())
print(text.swapcase())
print(text.strip())
print(text.lstrip())
print(text.rstrip())
str_result = text.replace('DKTE', 'KIT')
print(str_result)

print(text.find('to'))
print(text.count('e'))
print(text.startswith('H'))
print(text.startswith('welcome'))
print(text.startswith(' welcome'))
print(text.endswith('DKTE'))
print(text.endswith('DKTE '))

print(text.split())
print(text.split('e'))
# Out:
# my string -   welcome to DKTE
# 17
#  WELCOME TO DKTE
#  welcome to dkte
#  welcome to dkte
#  Welcome To Dkte
#  WELCOME TO dkte
# welcome to DKTE
# welcome to DKTE
#  welcome to DKTE
#  welcome to KIT
# 9
# 2
# False
# False
# True
# False
# True
# ['welcome', 'to', 'DKTE']
# [' w', 'lcom', ' to DKTE ']
