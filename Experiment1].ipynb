# %%
print("hello")
# Out:
# hello

# %%
print('Hello')
# Out:
# Hello

# %%
print("'Hello'")
# Out:
# 'Hello'

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello ',end='')
print('Dkte')
# Out:
# Hello Dkte

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
name="Poonam"
print(type(name))
print('Name = ',name)
# Out:
# <class 'str'>
# Name =  Poonam

# %%
print('Hello world','dkte')
# Out:
# Hello world dkte

# %%
print('Hello ','Dkte ','College ',sep='')
# Out:
# Hello Dkte College

# %%
name=input('Enter Your Name')
print('My name is ',name)
print(type(name))
# Out:
# Enter Your NamePoonam
# My name is  Poonam
# <class 'str'>

# %%
a=input("Enter first number ")
b=input("Enter second number ")
print('Sum',a+b)
print(type(a))
print(type(b))
# Out:
# Enter first number 12
# Enter second number 32
# Sum 1232
# <class 'str'>
# <class 'str'>

# %%
a=int(input("Enter first number "))
b=int(input("Enter second number "))
print('Sum',a+b)
print(type(a))
print(type(b))
# Out:
# Enter first number 12
# Enter second number 32
# Sum 44
# <class 'int'>
# <class 'int'>

# %%
age=int (input('Enter your age'))
print('My age after two years =',age+1)
# Out:
# Enter your age19
# My age after two years = 20

# %%
a=int(input("Enter first number "))
b=int(input("Enter second number "))
print('Sum = ',a+b)
print('Sub = ',a-b)
print('Product = ',a*b)
print('Div = ',a/b)
print(type(a))
print(type(b))3
# Out:
# Enter first number 9
# Enter second number 3
# Sum =  12
# Sub =  6
# Product =  27
# Div =  3.0
# <class 'int'>
# <class 'int'>

# %%
name="Poonam"
age=19
college="Dkte"
print(f'Hello my name is {name} and my age is {age} . I am studying in {college} ')
# Out:
# Hello my name is Poonam and my age is 19 . I am studying in Dkte

# %%
name = input('Enter Your Name ')
age = int(input('Enter your age '))
college = input('Enter your college ')

print(f'Hello my name is {name} and my age is {age} . I am studying in {college} ')

print('My age after one year = ',age+1)
# Out:
# Enter Your Name Poonam
# Enter your age 19
# Enter your college DKTE
# Hello my name is Poonam and my age is 19 . I am studying in DKTE
# My age after one year =  20
